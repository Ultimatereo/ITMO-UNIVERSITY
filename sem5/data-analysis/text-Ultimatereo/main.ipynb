# %% [markdown]
# # Подготовка и изучение данных

# %%
import pandas as pd

# Загрузка данных
anime = pd.read_csv('text.csv')

# Функция для фильтрации символов
allowed_chars = set(list("АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнопрстуфхцчшщъыьэюя0123456789 "))
mapping = lambda s: ''.join(list(filter(lambda c: c in allowed_chars, s)))

# Применение функции к столбцу с текстом песни
anime['description'] = anime['description'].apply(lambda s: mapping(str(s)))

# %%
anime.head()
# Out:
#                                  name  score    aired_on  \
# 0                        Ковбой Бибоп   8.75  1998-04-03
# 1  Легенда о новой Белоснежке Притиар   7.16  2001-04-04
# 2    Космический пират капитан Харлок   7.70  1978-03-14
# 3               История из эпохи Сёва   6.84  2011-04-04
# 4                        Югио! Зексал   6.42  2011-04-11
#
#                                          description  \
# 0  2071 год Человечество колонизировало всю Солне...
# 1  Химэно Аваюки   была обычной шестнадцатилетней...
# 2  2977 год Человечество перестало развиваться Вс...
# 3  Драматическая история семьи Ямадзаки в 39м год...
# 4  История разворачивается в далёком будущем где ...
#
#                                               genres
# 0                  ['Экшен', 'Фантастика', 'Космос']
# 1  ['Драма', 'Фэнтези', 'Романтика', 'Супер сила'...
# 2  ['Сэйнэн', 'Экшен', 'Приключения', 'Драма', 'Ф...
# 3                          ['Драма', 'Исторический']
# 4                      ['Экшен', 'Фэнтези', 'Сёнен']

# %%
import json
json.loads(anime['genres'][0].replace("'", '"'))
# Out:
# ['Экшен', 'Фантастика', 'Космос']

# %%
count_genres = {}
for row in anime['genres']:
    r_g = json.loads(row.replace("'", '"'))
    for g in r_g:
        if g not in count_genres:
            count_genres[g] = 0
        count_genres[g] += 1
print(len(count_genres))
print(sorted(count_genres.items(), key=lambda x: x[1]))
# Out:
# 40
# [('Эротика', 1), ('Машины', 7), ('Безумие', 19), ('Игры', 21), ('Демоны', 22), ('Полиция', 35), ('Гурман', 44), ('Вампиры', 59), ('Самураи', 63), ('Дзёсей', 68), ('Детское', 71), ('Работа', 75), ('Боевые искусства', 77), ('Триллер', 82), ('Космос', 89), ('Пародия', 91), ('Ужасы', 112), ('Музыка', 135), ('Психологическое', 143), ('Сёдзё', 152), ('Военное', 152), ('Спорт', 163), ('Супер сила', 181), ('Меха', 186), ('Гарем', 209), ('Исторический', 213), ('Повседневность', 250), ('Этти', 266), ('Детектив', 277), ('Сэйнэн', 349), ('Сверхъестественное', 381), ('Фантастика', 520), ('Приключения', 568), ('Сёнен', 612), ('Драма', 640), ('Романтика', 657), ('Школа', 697), ('Фэнтези', 864), ('Экшен', 1081), ('Комедия', 1221)]

# %% [markdown]
# # Морфологический анализ

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mansu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mansu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pymorphy3

morph = pymorphy3.MorphAnalyzer(lang='ru')
morph_analyze = lambda s: ' '.join([morph.parse(word)[0].normal_form for word in s.split()])

morph_analyze('Красивый и красивая были')
morphed_desc = anime['description'].apply(morph_analyze)

# %% [markdown]
# # Подсчёт 5% наиболее частых слов

# %%
from collections import Counter

words = ' '.join(morphed_desc).split(' ')
counts = Counter(words)
limit = int(0.05 * len(counts.keys()))
ordered = counts.most_common()
most_common = ordered[:limit]
print(most_common)
# Out:
# [('и', 11272), ('в', 10090), ('он', 4701), ('с', 4198), ('на', 4033), ('не', 3900), ('который', 2973), ('они', 2820), ('что', 2813), ('свой', 2529), ('она', 2036), ('но', 1891), ('это', 1840), ('по', 1634), ('как', 1610), ('быть', 1602), ('а', 1598), ('из', 1592), ('тот', 1475), ('к', 1382), ('мир', 1367), ('всё', 1317), ('о', 1267), ('человек', 1235), ('жизнь', 1191), ('этот', 1173), ('от', 1083), ('её', 1082), ('девушка', 1079), ('за', 1064), ('для', 1034), ('весь', 1014), ('один', 1000), ('новый', 982), ('друг', 949), ('стать', 939), ('школа', 922), ('так', 882), ('же', 882), ('чтобы', 881), ('время', 870), ('год', 861), ('себя', 836), ('только', 802), ('у', 749), ('однако', 725), ('мочь', 723), ('история', 654), ('герой', 628), ('когда', 619), ('сам', 602), ('сила', 588), ('после', 566), ('ещё', 564), ('имя', 551), ('такой', 543), ('другой', 534), ('вместе', 514), ('то', 509), ('день', 504), ('жить', 488), ('ли', 482), ('где', 474), ('теперь', 470), ('парень', 447), ('бы', 440), ('вот', 424), ('город', 418), ('каждый', 409), ('кто', 401), ('до', 399), ('ни', 396), ('первый', 394), ('уже', 394), ('под', 394), ('земля', 387), ('самый', 385), ('дело', 385), ('обычный', 383), ('ведь', 380), ('или', 378), ('семья', 359), ('даже', 359), ('клуб', 356), ('старший', 346), ('хороший', 345), ('являться', 342), ('девочка', 342), ('большой', 338), ('два', 335), ('однажды', 335), ('игра', 334), ('также', 333), ('смочь', 329), ('начинать', 328), ('становиться', 325), ('место', 322), ('оказаться', 321), ('война', 316), ('есть', 315), ('путь', 314), ('решать', 302), ('главный', 300), ('странный', 298), ('найти', 295), ('помощь', 292), ('команда', 292), ('дом', 291), ('способность', 284), ('академия', 283), ('пытаться', 282), ('цель', 279), ('япония', 278), ('известный', 276), ('решить', 274), ('работа', 273), ('предстоять', 273), ('если', 272), ('отец', 271), ('оказываться', 270), ('лишь', 268), ('раз', 266), ('просто', 265), ('событие', 263), ('изз', 260), ('должный', 258), ('проблема', 257), ('школьный', 254), ('наш', 253), ('приключение', 252), ('молодой', 252), ('сильный', 251), ('сестра', 248), ('подруга', 248), ('демон', 243), ('очень', 241), ('между', 239), ('конец', 238), ('тем', 235), ('хотеть', 234), ('встречать', 229), ('человечество', 228), ('мечта', 227), ('казаться', 227), ('работать', 227), ('знать', 225), ('любой', 222), ('будущее', 221), ('ученик', 219), ('загадочный', 216), ('судьба', 214), ('страна', 214), ('детство', 213), ('единственный', 212), ('получить', 212), ('полный', 211), ('чем', 208), ('при', 208), ('ребёнок', 208), ('класс', 207), ('три', 207), ('происходить', 205), ('без', 204), ('брат', 204), ('член', 203), ('поэтому', 201), ('нет', 201), ('таинственный', 199), ('группа', 199), ('помочь', 198), ('всегда', 194), ('способный', 194), ('юный', 193), ('рука', 193), ('иметь', 191), ('спасти', 191), ('вскоре', 190), ('пока', 187), ('пора', 186), ('маленький', 186), ('начинаться', 185), ('называть', 185), ('находиться', 185), ('перед', 185), ('любовь', 185), ('дух', 183), ('настоящий', 182), ('появляться', 182), ('узнать', 182), ('там', 182), ('момент', 182), ('монстр', 181), ('остаться', 181), ('собственный', 181), ('использовать', 180), ('японский', 177), ('мальчик', 177), ('последний', 176), ('несколько', 175), ('создать', 174), ('организация', 174), ('пройти', 172), ('огромный', 171), ('обладать', 171), ('юноша', 171), ('прийтись', 171), ('сделать', 169), ('над', 169), ('много', 168), ('существо', 168), ('ждать', 167), ('название', 167), ('отправляться', 167), ('планета', 167), ('чувство', 166), ('поиск', 165), ('смерть', 165), ('более', 165), ('мы', 164), ('желание', 164), ('учиться', 163), ('видеть', 163), ('сторона', 160), ('отношение', 159), ('продолжать', 159), ('второй', 157), ('ситуация', 157), ('какой', 156), ('мечтать', 155), ('вид', 155), ('среди', 155), ('часть', 154), ('враг', 154), ('аниме', 154), ('борьба', 153), ('совсем', 153), ('да', 153), ('компания', 153), ('ничего', 153), ('назад', 152), ('п ...

# %% [markdown]
# # Удаление частых слов и стоп слов

# %%
stopwords = nltk.corpus.stopwords.words('russian')

# %%
filter_significant = lambda s: ' '.join(
    list(filter(lambda w: not ((w, counts[w]) in most_common or (w, counts[w]) in stopwords), s.split()))
)

pd.DataFrame(anime['description'].apply(filter_significant)).to_csv('text_description.csv', index=False, header=False)

# %% [markdown]
# # Обучение модели для определения того аниме - фэнтези или нет

# %%
target = 'Фэнтези'

def is_target(r_g):
    return target in r_g

anime['isTarget'] = anime['genres'].apply(is_target)
anime
# Out:
#                                     name  score    aired_on  \
# 0                           Ковбой Бибоп   8.75  1998-04-03
# 1     Легенда о новой Белоснежке Притиар   7.16  2001-04-04
# 2       Космический пират капитан Харлок   7.70  1978-03-14
# 3                  История из эпохи Сёва   6.84  2011-04-04
# 4                           Югио! Зексал   6.42  2011-04-11
# ...                                  ...    ...         ...
# 2986                           Уровень Е   7.41  2011-01-11
# 2987                           Скет Данс   8.21  2011-04-07
# 2988                     Синий экзорцист   7.49  2011-04-17
# 2989                           Гинтама 2   9.03  2011-04-04
# 2990                        Голубое семя   7.00  1994-10-05
#
#                                             description  \
# 0     2071 год Человечество колонизировало всю Солне...
# 1     Химэно Аваюки   была обычной шестнадцатилетней...
# 2     2977 год Человечество перестало развиваться Вс...
# 3     Драматическая история семьи Ямадзаки в 39м год...
# 4     История разворачивается в далёком будущем где ...
# ...                                                 ...
# 2986  В наши дни на Земле проживают представители со...
# 2987  В академии Каймэй есть забавная троица  клуб п...
# 2988  Когда заходит солнце  наступает время демоновМ...
# 2989  Продолжение приключений Гинтоки   и его команд...
# 2990  Момидзи Фудзимия с детства воспитывалась так ч...
#
#                                                  genres  isTarget
# 0                     ['Экшен', 'Фантастика', 'Космос']     False
# 1     ['Драма', 'Фэнтези', 'Романтика', 'Супер сила'...      True
# 2     ['Сэйнэн', 'Экшен', 'Приключения', 'Драма', 'Ф...     False
# 3                             ['Драма', 'Исторический']     False
# 4                         ['Экшен', 'Фэнтези', 'Сёнен']      True
# ...                                                 ...       ...
# 2986                 ['Сёнен', 'Комедия', 'Фантастика']     False
# 2987                      ['Сёнен', 'Комедия', 'Школа']     False
# 2988             ['Сёнен', 'Экшен', 'Фэнтези', 'Школа']      True
# 2989  ['Сёнен', 'Экшен', 'Комедия', 'Фантастика', 'И...     False
# 2990  ['Экшен', 'Приключения', 'Комедия', 'Драма', '...     False
#
# [2991 rows x 6 columns]

# %%
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import extract_unigram_feats
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

# %%
desc_train, desc_test, target_train, target_test = (
    train_test_split(anime['description'], anime['isTarget'], test_size=0.3))

# %%
classifier = SklearnClassifier(MLPClassifier(hidden_layer_sizes=(5,)))
analyzer = SentimentAnalyzer()

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import BpeTrainer

tokenizer = Tokenizer(BPE())
trainer = BpeTrainer(vocab_size=5000)
tokenizer.pre_tokenizer = Whitespace()
tokenizer.train(['text_description.csv'], trainer)

# %%
train_size = len(desc_train)
train_data = [None] * train_size
for i in range(train_size):
    train_data[i] = (
        tokenizer.encode(desc_train.iloc[i]).tokens,
        target_train.iloc[i]
    )

# %%
unigram_feats = analyzer.unigram_word_feats(analyzer.all_words(train_data))
analyzer.add_feat_extractor(extract_unigram_feats, unigrams=unigram_feats)
train_set = analyzer.apply_features(train_data, labeled=True)
analyzer.train(classifier.train, train_set)
# Out:
# Training classifier
# <SklearnClassifier(MLPClassifier(hidden_layer_sizes=(5,)))>

# %%
from sklearn.metrics import accuracy_score

train_results = [None] * train_size
for i in range(train_size):
    train_results[i] = analyzer.classify(tokenizer.encode(desc_train.iloc[i]).tokens)

test_size = len(desc_test)
test_results = [None] * test_size
for i in range(test_size):
    test_results[i] = analyzer.classify(tokenizer.encode(desc_test.iloc[i]).tokens)
    
print("Train accuracy score: ", accuracy_score(target_train, train_results))
print("Test accuracy score: ", accuracy_score(target_test, test_results))
# Out:
# Train accuracy score:  1.0
# Test accuracy score:  0.7895322939866369
